# %% [markdown]
# # Visa Category Mapping and Dimension Table

# %% [markdown]
# - https://www.pluralsight.com/guides/extracting-data-html-beautifulsoup
# - https://travel.state.gov/content/travel/en/us-visas/visa-information-resources/all-visa-categories.html
# - https://travel.state.gov/content/dam/visas/Statistics/AnnualReports/FY2020AnnualReport/FY20AnnualReport-TableXVA.pdf

# %%
# importing the libraries
import pandas as pd
import re
from pprint import pprint

from bs4 import BeautifulSoup
import requests

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 80)

# %%
# specify url
url="https://travel.state.gov/content/travel/en/us-visas/visa-information-resources/all-visa-categories.html"

# Make a GET request to fetch the raw HTML content
html_content = requests.get(url).text

# Parse the html content
soup = BeautifulSoup(html_content, "html")
#print(soup.prettify()) # print the parsed data of html

# %%
# get box header visa category types

categories = soup.find_all("h4", attrs={"class": "tsg-rwd-accordion-header-name-frame"})
categories_list = [category.text.strip() for category in categories]
categories_list
# Out:
# ['Nonimmigrant Visa Categories', 'Immigrant Visa Categories']

# %%
# obtain the two separate tables

tables = soup.find_all("table", attrs={"class": "grid"})

# %%
# generate immigrant visa categories from tables

def get_dataframe(table, visa_category):
    group = []
    data = []

    tr = table.tbody.find_all("tr")
    for i in range(len(tr)):
        td = tr[i].find_all("td")
        #print(len(td))

        if td[0].b != None:
            group.append(td[0].text.strip())
        else:
            data.append({'visa_category':visa_category,'visa_group':group[-1],'visa_desc':td[0].text.strip(), 'visa':td[1].text.strip() })

    return pd.DataFrame(data)

# %%
# non-immigrants, immigrants df
non_df = get_dataframe(tables[0], categories_list[0])
im_df = get_dataframe(tables[1], categories_list[1])

# %%
im_df
# Out:
#                 visa_category                             visa_group  \
# 0   Immigrant Visa Categories  Immediate Relative & Family Sponsored
# 1   Immigrant Visa Categories  Immediate Relative & Family Sponsored
# 2   Immigrant Visa Categories  Immediate Relative & Family Sponsored
# 3   Immigrant Visa Categories  Immediate Relative & Family Sponsored
# 4   Immigrant Visa Categories  Immediate Relative & Family Sponsored
# 5   Immigrant Visa Categories  Immediate Relative & Family Sponsored
# 6   Immigrant Visa Categories        Employer Sponsored – Employment
# 7   Immigrant Visa Categories        Employer Sponsored – Employment
# 8   Immigrant Visa Categories        Employer Sponsored – Employment
# 9   Immigrant Visa Categories        Employer Sponsored – Employment
# 10  Immigrant Visa Categories        Employer Sponsored – Employment
# 11  Immigrant Visa Categories                       Other Immigrants
# 12  Immigrant Visa Categories                       Other Immigrants
#
#                                                                                                                                                                                                                                                                                             visa_desc  \
# 0                                                                                                                                                                                                                                                                            Spouse of a U.S. Citizen
# 1                                                                                                                                                                                                                           Spouse of a U.S. Citizen awaiting approval of an I-130 immigrant petition
# 2                                                                                                                                                                                                                                                      Fiancé(e) to marry U.S. Citizen & live in U.S.
# 3                                                                                                                                                                                                                                           Intercountry Adoption of Orphan Children by U.S. Citizens
# 4                                                                                                                                                                                                                                                             Certain Family Members of U.S. Citizens
# 5                                                                                                                                                                                                                                                Certain Family Members of Lawful Permanent Residents
# 6   Employment-Based Immigrants, including  (preference group):\n\nPriority workers [First]\nProfessionals Holding Advanced Degrees and Persons of Exceptional Ability [Second]\nProfessionals and Other Workers [Third]\nEmployment Creation/Investors [Fifth]\nCertain Special Immigrants: [Fourth]
# 7                                                                                                                                                                                                                                                                                   Religious Workers
# 8                                                                                                                                                                                                                                                           Iraqi and Afghan Translators/Interpreters
# 9                                                                                                                                                                                                                                              Iraqis Who Worked for/on Behalf of the U.S. Government
# 10                                                                                                                                                                                                                                            Afghans Who Worked for/on Behalf of the U.S. Government
# 11                                                                                                                                                                                                                                                                           Diversity Immigrant Visa
# 12                                                                                                                                                                                                                                                                                 Returning Resident
#
#                                                        visa
# 0                                                  IR1, CR1
# 1                                                     K-3 *
# 2                                                     K-1 *
# 3                                        IR3, IH3, IR4, IH4
# 4                                 IR2, CR2, IR5, F1, F3, F4
# 5                                                  F2A, F2B
# 6   E1\nE2\n\n\n\nE3, EW3\n\n\nC5, T5, R5, I5\n\nS (many**)
# 7                                                    SD, SR
# 8                                                        SI
# 9                                                        SQ
# 10                                                       SQ
# 11                                                       DV
# 12                                                       SB

# %% [markdown]
# - clean row 6: Employment Based Immigrants

# %%
# get relevant visa descriptions
visa_cat =  im_df.loc[6][0]
visa_group = im_df.loc[6][1]
visa_desc = im_df.loc[6][2].split('\n')
visa_desc_clean = visa_desc[2:]
#pprint(visa_desc_clean)

# get relevant visa codes
visa_code = im_df.loc[6][3].split('\n')
visa_code_clean = [x for x in visa_code if x != '' ]
#pprint(visa_code_clean)

# combine results in dataframe
im_df_6 = pd.DataFrame(list(zip([visa_cat] * 5 , [visa_group] * 5, visa_desc_clean,visa_code_clean)))
im_df_6.columns = ['visa_category', 'visa_group', 'visa_desc', 'visa']
im_df_6
# Out:
#                visa_category                       visa_group  \
# 0  Immigrant Visa Categories  Employer Sponsored – Employment
# 1  Immigrant Visa Categories  Employer Sponsored – Employment
# 2  Immigrant Visa Categories  Employer Sponsored – Employment
# 3  Immigrant Visa Categories  Employer Sponsored – Employment
# 4  Immigrant Visa Categories  Employer Sponsored – Employment
#
#                                                                             visa_desc  \
# 0                                                            Priority workers [First]
# 1  Professionals Holding Advanced Degrees and Persons of Exceptional Ability [Second]
# 2                                             Professionals and Other Workers [Third]
# 3                                               Employment Creation/Investors [Fifth]
# 4                                                Certain Special Immigrants: [Fourth]
#
#              visa
# 0              E1
# 1              E2
# 2         E3, EW3
# 3  C5, T5, R5, I5
# 4      S (many**)

# %%
# append and delete index= 6
im_df_clean = im_df.append(im_df_6)
im_df_clean = im_df_clean.drop(6)

# combine immigrants and non-immigrants dataset
df = im_df_clean.append(non_df)


# split colums to rows with multiple visa codes
splitter = ",|\n|/"

l = []
for i, row in df.iterrows():
    visa_codes = re.split(splitter, row['visa'])
    for code in visa_codes:
        l.append((row['visa_category'], row['visa_group'], row['visa_desc'], code))
        

# generate new dataframe with splitted columns
df = pd.DataFrame(l)
df.columns = ['visa_category', 'visa_group', 'visa_desc', 'visa']


# clean visa codes and generate a mapping column to fit the format in the I94 data
df['visa_map'] = df['visa'].str.extract('([A-Z]{1,5}-?[A-Z0-9]{0,3}[A-Za-z\s\-]*)',expand=False).str.replace("-","").str.replace(" ","")
df.sample(5)
# Out:
#                    visa_category                             visa_group  \
# 44  Nonimmigrant Visa Categories                      Purpose of Travel
# 23     Immigrant Visa Categories        Employer Sponsored – Employment
# 21     Immigrant Visa Categories                       Other Immigrants
# 65  Nonimmigrant Visa Categories                      Purpose of Travel
# 14     Immigrant Visa Categories  Immediate Relative & Family Sponsored
#
#                                                     visa_desc visa visa_map
# 44  Foreign military personnel stationed in the United States  A-2       A2
# 23                                   Priority workers [First]   E1       E1
# 21                                   Diversity Immigrant Visa   DV       DV
# 65                        Tourism, vacation, pleasure visitor  B-2       B2
# 14       Certain Family Members of Lawful Permanent Residents  F2A      F2A

# %%
# find duplicates in visa_map and filter

df['duplicate_count'] = df.groupby(["visa_map"])['visa_desc'].transform('count')
df_duplicates = df[df['duplicate_count'] > 1].sort_values(by='visa_map')
df_duplicates
# Out:
#                    visa_category                       visa_group  \
# 32  Nonimmigrant Visa Categories                Purpose of Travel
# 36  Nonimmigrant Visa Categories                Purpose of Travel
# 40  Nonimmigrant Visa Categories                Purpose of Travel
# 51  Nonimmigrant Visa Categories                Purpose of Travel
# 65  Nonimmigrant Visa Categories                Purpose of Travel
# 25     Immigrant Visa Categories  Employer Sponsored – Employment
# 34  Nonimmigrant Visa Categories                Purpose of Travel
# 57  Nonimmigrant Visa Categories                Purpose of Travel
# 60  Nonimmigrant Visa Categories                Purpose of Travel
# 33  Nonimmigrant Visa Categories                Purpose of Travel
# 43  Nonimmigrant Visa Categories                Purpose of Travel
# 56  Nonimmigrant Visa Categories                Purpose of Travel
# 58  Nonimmigrant Visa Categories                Purpose of Travel
# 19     Immigrant Visa Categories  Employer Sponsored – Employment
# 20     Immigrant Visa Categories  Employer Sponsored – Employment
#
#                                                                         visa_desc  \
# 32              Athlete, amateur or professional (competing for prize money only)
# 36                                                               Business visitor
# 40  Domestic employee or nanny - must be accompanying a foreign national employer
# 51                                                 Medical treatment, visitor for
# 65                                            Tourism, vacation, pleasure visitor
# 25                                        Professionals and Other Workers [Third]
# 34                                              Australian professional specialty
# 57                                                                      Physician
# 60         Specialty occupations in fields requiring highly specialized knowledge
# 33                                                     Au pair (exchange visitor)
# 43                                                               Exchange visitor
# 56                                                                      Physician
# 58                                 Professor, scholar, teacher (exchange visitor)
# 19                         Iraqis Who Worked for/on Behalf of the U.S. Government
# 20                        Afghans Who Worked for/on Behalf of the U.S. Government
#
#      visa visa_map  duplicate_count
# 32    B-1       B1              3.0
# 36    B-1       B1              3.0
# 40    B-1       B1              3.0
# 51    B-2       B2              2.0
# 65    B-2       B2              2.0
# 25     E3       E3              2.0
# 34    E-3       E3              2.0
# 57   H-1B      H1B              2.0
# 60   H-1B      H1B              2.0
# 33      J        J              4.0
# 43      J        J              4.0
# 56     J         J              4.0
# 58      J        J              4.0
# 19     SQ       SQ              2.0
# 20     SQ       SQ              2.0

# %%
# manually select the ones to keep (most generic descriptions)
# drop SQ, no differentiation

# keep
ind = [36, 65, 25, 60, 43]

# delete
ind_drop = [x for x in df_duplicates.index if x not in ind]
ind_drop
# Out:
# [32, 40, 51, 34, 57, 33, 56, 58, 19, 20]

# %%
# remove duplicates from dataframe
df = df.drop(ind_drop, axis=0)

# check duplicate elimination
(df.groupby(["visa_map"])['visa_desc'].count() > 1).sum()
# Out:
# 0

# %%
# final cleaning cleaning

df = df.dropna()
df = df.drop('duplicate_count', axis=1)

# add dummy column if mapping is not found
df = pd.DataFrame.from_dict({'visa_category':['Unknown Visa Categories'],
                             'visa_group':['Unknown Visa'],
                             'visa_desc':['Unknown'],
                             'visa':[''],
                             'visa_map':['']}).append(df).reset_index(drop=True)

# add id used as a primary key
df['visa_id'] = df.index + 1

# %%
# replace line break
df['visa_desc'] = df['visa_desc'].str.replace("\n"," ")

# %%
# select relevant columns for mapping / dimension table

df = df[['visa_category','visa_group','visa_desc','visa_map','visa_id']]
df = df.rename(columns={'visa_map':'visa'})

# %%
df.head()
# Out:
#                visa_category                             visa_group  \
# 0    Unknown Visa Categories                           Unknown Visa
# 1  Immigrant Visa Categories  Immediate Relative & Family Sponsored
# 2  Immigrant Visa Categories  Immediate Relative & Family Sponsored
# 3  Immigrant Visa Categories  Immediate Relative & Family Sponsored
# 4  Immigrant Visa Categories  Immediate Relative & Family Sponsored
#
#                                                                    visa_desc  \
# 0                                                                    Unknown
# 1                                                   Spouse of a U.S. Citizen
# 2                                                   Spouse of a U.S. Citizen
# 3  Spouse of a U.S. Citizen awaiting approval of an I-130 immigrant petition
# 4                             Fiancé(e) to marry U.S. Citizen & live in U.S.
#
#   visa  visa_id
# 0             1
# 1  IR1        2
# 2  CR1        3
# 3   K3        4
# 4   K1        5

# %%
# write out dimension table to final destination
df.to_csv('../staging/visa_categories.csv', sep=";", index=False)
